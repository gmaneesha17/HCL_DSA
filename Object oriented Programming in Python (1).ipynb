# %%
class Student:
    school_name="ABC"
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
s1=Student("MANI",100)
print(s1.name,s1.rollno,Student.school_name)
Student.school_name="XYZ"
print(s1.name,s1.rollno,Student.school_name)
# Out:
# MANI 100 ABC
# MANI 100 XYZ

# %%
class BankAccount:
    def __init__(self,balance):
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
    def withdraw(self,amount):
        if self.balance>=amount:
            self.balance-=amount
        else:
            print("Insufficient funds")
    def get_balance(self):
        return self.balance
b=BankAccount(1000)
b.deposit(500)
b.withdraw(500)
print(b.get_balance())
# Out:
# 1000

# %%
class vector:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        return vector(self.x+other.x,self.y+other.y)
    def display(self):
        print(f"{self.x},{self.y}")
v1=vector(1,2)
v2=vector(3,4)
v3=v1+v2
v3.display()
# Out:
# 4,6

# %%
class MathUtils:
    @staticmethod
    def add(a,b):
        return a+b
    @classmethod
    def get_class_name(cls):
        return cls.__name__
# m=MathUtils()
print(MathUtils.add(10,12))
print(MathUtils.get_class_name())
# Out:
# 22
# MathUtils
