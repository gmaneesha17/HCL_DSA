# %%
import re
def Invoice_Validate(i):
    p=r'^INV-(\d{4})(0[1-9]|1[0-2])-(\d{6})$'
    match=re.match(p,i)
    if not match:
        return False
    year,month,serial=match.groups()
    cs=sum(int(d) for d in serial)
    return cs%2==0
i=input()
if Invoice_Validate(i):
    print("Valid")
else:
    print("Invalid")
# Out:
#  INV-202412-000123
# Valid
