# %%
n=int(input())
c=0
for i in range(1,n//2+1):
    if n%i==0:
        c=c+1
print("No.of Divisors:",c)
# Out:
#  28
# No.of Divisors: 5

# %%
n=int(input())
for i in range(n//2,0,-1):
    if n%i==0:
        print("Largest divisor:",i)
        break
# Out:
#  28
# Largest divisor: 14
