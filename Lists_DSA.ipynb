# %%
l=[1,2,3]
for x in l:
    print(x)
print(*l)
# Out:
# 1
# 2
# 3
# 1 2 3

# %%
l=[1,2,3]
l.extend([4,5,6])
print(*l)
# Out:
# 1 2 3 4 5 6

# %%
l=[1,2,3]
l.pop(1)    #index 1 - 2
print(*l)
# Out:
# 1 3

# %%
l=[1,2,3]
print(l.index(2))
# Out:
# 1

# %%
l=[1,2,3]
l.remove(3)   # element
print(*l)
# Out:
# 1 2

# %%
l=[1,2,3]
del l[2]  #index 2-  3
print(*l)
# Out:
# 1 2

# %%
l=[1,2,3,4,5,6]
print(*l)
l.sort(reverse=True)
# Out:
# 1 2 3 4 5 6

# %%
l=[6,5,4,3,2,1]
l.sort()
print(*l)
# Out:
# 1 2 3 4 5 6

# %%
l=[1,2,3]
print(len(l))
print(max(l))
print(min(l))
print(sum(l))
# Out:
# 3
# 3
# 1
# 6
