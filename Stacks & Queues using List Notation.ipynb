# %%
st=[]
st.append(10)
st.append(20)
st.append(30)
print(st)
a=st.pop()
print(a)
print(st)
print(st[-1])
# Out:
# [10, 20, 30]
# 30
# [10, 20]
# 20

# %%
queue=[]
queue.append(10)
queue.append(20)
queue.append(30)
print(queue)
b=queue.pop(0)
print(b)
print(queue)
print(queue[0])
# Out:
# [10, 20, 30]
# 10
# [20, 30]
# 20
